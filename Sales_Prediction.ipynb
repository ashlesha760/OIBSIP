# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read Dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bd2dfae3-9235-4434-9199-3d0c8a7de42b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bd2dfae3-9235-4434-9199-3d0c8a7de42b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['Advertising.csv']))
print(df)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Analyze Dataset

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# Radio         float64
# Newspaper     float64
# Sales         float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# ## Visualize

# %%
df1= df.drop(['Unnamed: 0'], axis=1)

# %%
print(df1)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
sns.pairplot(df1, hue ='Sales')

# %%
sns.lineplot(data = df1, x='TV', y='Sales')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.lineplot(data = df1, x='Radio', y='Sales')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.lineplot(data = df1, x='Newspaper', y='Sales')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
sns.scatterplot(data=df1, x='TV', y='Sales')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.scatterplot(data=df1, x='Newspaper', y='Sales')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
sns.scatterplot(data=df1, x='Radio', y='Sales')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
plt.figure(figsize=(50,50))
sns.barplot(data=df1, x='TV', y='Sales')
#we can use figure size in case the digits or entries on the axis are not visible
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.barplot(data=df1, x='Newspaper', y='Sales')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
sns.barplot(data=df1, x='Radio', y='Sales')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>
